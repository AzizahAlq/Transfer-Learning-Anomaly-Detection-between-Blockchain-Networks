# %% [markdown]
# # **Download Bitcoin BlockChain DATASET**

# %% [markdown]
# ## Steps:
#
# 1. COnnect to Kaggle API
# 2. Connect Gdrive to save Data
# 3. Provide API call to download the dataset

# %% [markdown]
# Install Kaggle CLI:

# %%
pip install kaggle

# %% [markdown]
# Get Kaggle API Key:
#
# 1. Go to your Kaggle account settings and create a new API token.
# 2. Download the kaggle.json file.
# 3. Upload it to the Colab Environment

# %% [markdown]
# Set up API credentials:
# - Move the kaggle.json file to the appropriate directory:

# %%
# !mkdir ~/.kaggle

# %%
# !mv kaggle.json ~/.kaggle/
# Out:
# mv: cannot stat 'kaggle.json': No such file or directory

# %%
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory

# %% [markdown]
# Connect Gdrive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Download the data from kaggle

# %%
import os
os.system('kaggle datasets download -d omershafiq/bitcoin-network-transactional-metadata')
# Out:
# 0

# %%
os.system('kaggle datasets download -d omershafiq/bitcoin-hacks-2010to2013') #hacksdata
# Out:
# 0

# %% [markdown]
# Unzip the Data to Local Gdrive Folder

# %%
zip_file_path = '/content/bitcoin-network-transactional-metadata.zip'
hacks_file_path = '/content/bitcoin-hacks-2010to2013.zip'
destination_dir = '/content/drive/MyDrive/BlockChainAnomaly/Data'

# %%
# !unzip -q {zip_file_path} -d {destination_dir}
# Out:
# replace /content/drive/MyDrive/BlockChainAnomaly/Data/._DG_out.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace /content/drive/MyDrive/BlockChainAnomaly/Data/DG_out.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# y

# %%
# !unzip -q {hacks_file_path} -d {destination_dir}
# Out:
# replace /content/drive/MyDrive/BlockChainAnomaly/Data/bitcoin_hacks_2010to2013/bitcoin_hacks_2010_2013.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace /content/drive/MyDrive/BlockChainAnomaly/Data/bitcoin_hacks_2010to2013/malicious_tx_in.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace /content/drive/MyDrive/BlockChainAnomaly/Data/bitcoin_hacks_2010to2013/malicious_tx_out.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace /content/drive/MyDrive/BlockChainAnomaly/Data/bitcoin_hacks_2010to2013/other/anomalies_loss_tx.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace /content/drive/MyDrive/BlockChainAnomaly/Data/bitcoin_hacks_2010to2013/other/anomalies_misc_tx.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace /content/drive/MyDrive/BlockChainAnomaly/Data/bitcoin_hacks_2010to2013/other/anomalies_seizure1_tx.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# ...

# %% [markdown]
# :Data has been downloaded Succesfully. Now, We proceed further with data EDA and Preprocessing.
